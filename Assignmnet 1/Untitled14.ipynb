# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
from sklearn import linear_model

# %%
df = pd.read_excel("Untitled spreadsheet.xlsx")

# %%
df
# Out:
#     Production Budget  Marketing Spend  Theaters  Runtime  \
# 0           150000000         75000000      4000      120
# 1            20000000         10000000      2500       95
# 2            50000000         30000000      3200      110
# 3           250000000        120000000      4500      150
# 4            10000000          5000000      1500       85
# 5            75000000         40000000      3500      115
# 6           120000000         60000000      3800      130
# 7           180000000         90000000      4200      140
# 8            30000000         15000000      2800      100
# 9            90000000         45000000      3600      125
# 10           40000000         20000000      3000      105
# 11          200000000        100000000      4300      145
# 12           15000000          8000000      2000       90
# 13           60000000         35000000      3400      112
# 14          140000000         70000000      3900      135
# ...

# %%
plt.xlabel("Theaters")
plt.ylabel("Runtime")
plt.scatter(df.Theaters, df.Runtime )

# %%
lr = linear_model.LinearRegression()

# %%
lr.fit(df[['Theaters']], df.Runtime)
# Out:
# LinearRegression()

# %%
lr.predict([[2800]])
# Out:
# C:\Users\abdulmustafa\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([104.71799484])

# %%
lr.coef_
# Out:
# array([0.02387571])

# %%
lr.intercept_
# Out:
# np.float64(37.86601962857907)

# %%
value = 2800*0.02387571 + 37.86
value
# Out:
# 104.711988

# %%
plt.xlabel("Theaters")
plt.ylabel("Runtime")
plt.scatter(df.Theaters, df.Runtime )
plt.plot(df.Theaters, lr.predict(df[['Theaters']]), color='red')
